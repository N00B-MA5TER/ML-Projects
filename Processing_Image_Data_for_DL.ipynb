# %% [markdown]
# <a href="https://colab.research.google.com/github/N00B-MA5TER/ML-Projects/blob/main/Processing_Image_Data_for_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget 'https://photos.demandstudios.com/getty/article/83/128/460873489.jpg'
# Out:
# --2025-09-22 17:39:47--  https://photos.demandstudios.com/getty/article/83/128/460873489.jpg
# Resolving photos.demandstudios.com (photos.demandstudios.com)... 3.169.149.41, 3.169.149.104, 3.169.149.66, ...
# Connecting to photos.demandstudios.com (photos.demandstudios.com)|3.169.149.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1329021 (1.3M) [image/jpeg]
# Saving to: ‘460873489.jpg’
#
# 460873489.jpg       100%[===================>]   1.27M  --.-KB/s    in 0.06s
#
# 2025-09-22 17:39:47 (20.0 MB/s) - ‘460873489.jpg’ saved [1329021/1329021]

# %% [markdown]
# **Libraries that can be used for image processing**
#
# 1. matplotlib.image
#
# 2. Pillow
#
# 3. OpenCV(cv2)

# %%
# importing the image module from matplotlib library
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module
img = mpimg.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (800, 800, 3)

# %%
print(img)
# Out:
# [[[162 180 126]
#   [162 180 126]
#   [161 179 125]
#   ...
#   [142 146 131]
#   [147 152 137]
#   [151 156 140]]
#
#  [[159 177 123]
#   [159 177 123]
#   [161 179 125]
#   ...
#   [140 145 130]
#   [146 151 136]
#   [150 155 139]]
#
#  [[153 171 119]
#   [155 173 121]
#   [160 178 126]
#   ...
#   [138 143 128]
#   [144 149 133]
#   [149 153 138]]
#
#  ...
#
#  [[128 110  96]
#   [131 113  98]
#   [125 107  92]
#   ...
#   [ 75  39  19]
#   [102  66  35]
#   [ 92  56  21]]
#
#  [[135 117 105]
#   [ 89  70  58]
#   [ 62  44  32]
#   ...
#   [ 73  37  17]
#   [110  75  39]
#   [116  82  39]]
#
#  [[ 40  21   9]
#   [ 32  13   1]
#   [ 38  19   7]
#   ...
#   [ 75  39  19]
#   [109  74  38]
#   [123  89  44]]]

# %%
# displaying the image from numpy array
img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using Pillow library

# %%
from PIL import Image

# %%
img = Image.open('/content/dog.jpg')
img_resized = img.resize((2000,2000))

# %%
print(img_resized)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x2000 at 0x7C8FF5D51C70>

# %%
img_resized.save('dog_image_resized.jpg')

# %%
# displaying the image from numpy array
img_res = mpimg.imread('/content/dog_image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (2000, 2000, 3)

# %% [markdown]
# **Converting RGB images to Grayscale image using OpenCV**

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (800, 800, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (800, 800)

# %% [markdown]
# cv2.imshow() will display the image, but this will not be allowed in Google Colab
#
# **from google.colab.patches import cv2_imshow**

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x800>

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=800x800>

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
